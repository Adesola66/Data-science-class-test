# %% [markdown]
# # DATA SCIENCE CLASS TEST

# %% [markdown]
# # NAME: DAVID BRAIMOH

# %% [markdown]
# # PHONE NUMBER: 08037041507
# # EMAIL ADDRESS : DBRAIMOH@GMAIL.COM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Bio = {"Name":["Abayomi", "Kemi", "Kunle", "Adesuwa", "Elisha", "Dre", "Kayla", "Lydia", "Grace", "Emelda"],
       "Age":[23, 30, 40, 50, 60, 35, 32, 22, 74, 34],
      "School": ["OAU", "Unimaid", "Unical", "Unijos", "Uniben", "Unilag", "Uniuyo", "ABU", "Kadsu", "Covenant"]}

# %%
df = pd.DataFrame(Bio)

# %%
df
# Out:
#       Name  Age    School
# 0  Abayomi   23       OAU
# 1     Kemi   30   Unimaid
# 2    Kunle   40    Unical
# 3  Adesuwa   50    Unijos
# 4   Elisha   60    Uniben
# 5      Dre   35    Unilag
# 6    Kayla   32    Uniuyo
# 7    Lydia   22       ABU
# 8    Grace   74     Kadsu
# 9   Emelda   34  Covenant

# %%
df["Name"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
df["Name"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Name"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Name'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = [23, 30, 40, 50, 60, 35, 32, 22, 74, 34]
Y = ["OAU", "Unimaid", "Unical", "Unijos", "Uniben", "Unilag", "Uniuyo", "ABU", "Kadsu", "Covenant"]

# %%
plt.scatter (X, Y)
plt.show ()

# %% [markdown]
# # WHAT IS DATA SCIENCE AND DATA ANALYSIS?

# %%
# Data is that field of the study that uses methods icluding statistics, mathematics, machine learning and predictive analytics to draw insights from data and make data-driven decision.

# %%
# Data Analysis is the process of inspecting, cleansing,transforming, and modeling data to discover useful information, draw conclusions and support decison-making.

# %% [markdown]
# # LIFECYLCLE OF DATA SCIENCE

# %%
#1. IDENTIFY PROBLEM
#2. COLLECT DATA
#3. DATA CLEANING
#4. DATA ANALYSIS
#5. DATA MODELING
#6. MODEL DEPLOYMENT

# %% [markdown]
# # TOOLS USED IN DATA SCIENCE

# %%
#1. PYRTHON
#2. JUPYTER NOTEBOOK
#3. EXCEL
#4. GOOGLE COLAB
